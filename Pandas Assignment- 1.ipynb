# %% [markdown]
# ## Pandas_Series_DataFrame_creation
# - A.Pandas Series

# %%
import pandas as pd

# %%
temps=pd.Series( [12, 3, 4, 4, 5])
temps
# Out:
# 0    12
# 1     3
# 2     4
# 3     4
# 4     5
# dtype: int64

# %% [markdown]
# Create a Pandas Series from the following tuple of employee names:
#
#  employees = ("Amit", "Neha", "Raj", "Sara")

# %%
employee=pd.Series(["Amit","Neha","Raj","Sara"])
print(employee)
# Out:
# 0    Amit
# 1    Neha
# 2     Raj
# 3    Sara
# dtype: object

# %% [markdown]
# Create a Pandas Series from the following set of unique product IDs:
#
#  product_ids = {101, 102, 103, 104}

# %%
product_Ids=pd.Series(list({101,102,103,104}))
product_Ids
# Out:
# 0    104
# 1    101
# 2    102
# 3    103
# dtype: int64

# %% [markdown]
# Create a Pandas Series from the following dictionary where keys are subjects and values are marks:
#
#  marks = {
#     "Math": 85,
#     "Science": 90,
#     "English": 88
# }

# %%
marks={"Maths":85,"Science":90,"English":88}
df=pd.Series(marks)
df
# Out:
# Maths      85
# Science    90
# English    88
# dtype: int64

# %% [markdown]
# Create a Pandas Series from the following NumPy array of monthly expenses:
#
# - import numpy as np
# - expenses = np.array([12000, 15000, 11000, 18000])

# %%
import numpy as np

# %%
expenes=np.array([12000,15000,11000,18000])
df=pd.Series(expenes)
print(df)
# Out:
# 0    12000
# 1    15000
# 2    11000
# 3    18000
# dtype: int64

# %% [markdown]
# Print the index and values of the Series created from temps.

# %%
pd.Series(temps)
# Out:
# 0    12
# 1     3
# 2     4
# 3     4
# 4     5
# dtype: int64

# %%
print("Temps",temps.index)
print("Values",temps.values)
# Out:
# Temps RangeIndex(start=0, stop=5, step=1)
# Values [12  3  4  4  5]

# %% [markdown]
# Print the index and values of the Series created from employees.

# %%
print("Index fromm employees:",employee.index)
print("values from employees:",employee.values)
# Out:
# Index fromm employees: RangeIndex(start=0, stop=4, step=1)
# values from employees: ['Amit' 'Neha' 'Raj' 'Sara']

# %% [markdown]
# Print the index and values of the Series created from marks.

# %%
print("Index from marks:",df.index)
print("values from marks:",df.values)
# Out:
# Index from marks: RangeIndex(start=0, stop=4, step=1)
# values from marks: [12000 15000 11000 18000]

# %% [markdown]
# Create a Series using the following list and manually assign custom index labels:
# scores = [70, 80, 90]

# %%
scores=[70,80,90]

# %%
scores=pd.Series(scores,index=["Maths","Science","Telugu"])
scores
# Out:
# Maths      70
# Science    80
# Telugu     90
# dtype: int64

# %% [markdown]
# Create a Series from the dictionary marks and display only its values.

# %%
series={"Maths":85,"Science":90,"English":88}
marks=pd.Series(series)
print(series.values())
# Out:
# dict_values([85, 90, 88])

# %% [markdown]
# Create a Pandas Series from the following NumPy array of monthly expenses:
#
# - import numpy as np
# - expenses = np.array([12000, 15000, 11000, 18000])

# %%
import numpy as np
import pandas as pd

# %%
expenses = np.array([12000, 15000, 11000, 18000])

# %%
df=pd.Series(expenses)
print(df)
# Out:
# 0    12000
# 1    15000
# 2    11000
# 3    18000
# dtype: int64

# %% [markdown]
# Print the index and values of the Series created from temps.

# %%
print("index from temps:",temps.index)
print("values from temps:",temps.values)
# Out:
# index from temps: RangeIndex(start=0, stop=5, step=1)
# values from temps: [12  3  4  4  5]

# %% [markdown]
# Print the index and values of the Series created from employees.

# %%
print("employee index:",employee.index)
print("employee values:",employee.values)
# Out:
# employee index: RangeIndex(start=0, stop=4, step=1)
# employee values: ['Amit' 'Neha' 'Raj' 'Sara']

# %% [markdown]
# Print the index and values of the Series created from marks.

# %%
print("index from marks:",marks.index)
print('values from marks:',marks.values)
# Out:
# index from marks: Index(['Maths', 'Science', 'English'], dtype='object')
# values from marks: [85 90 88]

# %% [markdown]
# Create a Series using the following list and manually assign custom index labels:
# - scores = [70, 80, 90]
# - Custom index:
# - ["Test1", "Test2", "Test3"]

# %%
scoress=[70,80,90]
df=pd.Series(scoress,index=["Test1","Test2","Test3"])
print(df)
# Out:
# Test1    70
# Test2    80
# Test3    90
# dtype: int64

# %% [markdown]
# Create a Series from the dictionary marks and display only its values.

# %%
dictionary={"Maths":85,"Science":90,"English":88}
df=pd.Series(dictionary)
print(df.values)
# Out:
# [85 90 88]

# %% [markdown]
# Convert the following list of Boolean values into a Pandas Series:
# flags = [True, False, True, True]

# %%
flags = [True, False, True, True]
series = pd.Series(flags)

print(series)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %% [markdown]
# Create a Series from the NumPy array expenses and check its data type.

# %% [markdown]
# print(type(expenses))

# %% [markdown]
# ## B.Pandas DataFrame

# %% [markdown]
# Create a Pandas DataFrame from the following list of lists representing student ID, name, and score:
#
#  - Students = [
#     [1, "Rahul", 85],
#     [2, "Sneha", 92],
#     [3, "Arjun", 78]
# ]

# %%
data={"ID":[1,2,3],
    "Students" : ["Rahul", "Sneha" ,"Arjun"],
"Score":[85,92,78]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    ID Students  Score
# 0   1    Rahul     85
# 1   2    Sneha     92
# 2   3    Arjun     78

# %% [markdown]
# Create a Pandas DataFrame from the following dictionary of lists:
#
#  - products = {
#   -   "Product": ["Pen", "Book", "Pencil"],
#    -  "Price": [10, 50, 5],
#    -  "Quantity": [100, 40, 200]
# }

# %%
data={"Product":["Pen","Book","Pencil"],
     "Price":[10,50,5],
     "Quantity":[100,40,200]}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Product  Price  Quantity
# 0     Pen     10       100
# 1    Book     50        40
# 2  Pencil      5       200

# %% [markdown]
# Create a Pandas DataFrame from the following NumPy array representing employee data:
#
#  emp_data = np.array([
#     [101, "John", 50000],
#     [102, "Alice", 60000],
#     [103, "Bob", 55000]
# ])

# %%
emp_data = np.array([
    [101, "John", 50000],
    [102, "Alice", 60000],
    [103, "Bob", 55000]
])
df=pd.DataFrame(emp_data)
df
# Out:
#      0      1      2
# 0  101   John  50000
# 1  102  Alice  60000
# 2  103    Bob  55000

# %%
df.columns=[["Emp_Id","Name","Salary"]]

# %%
df
# Out:
#   Emp_Id   Name Salary
# 0    101   John  50000
# 1    102  Alice  60000
# 2    103    Bob  55000

# %% [markdown]
# Assign column names ["ID", "Name", "Score"] to the students DataFrame.

# %%
data={"ID":[1,2,3],
    "Students" : ["Rahul", "Sneha" ,"Arjun"],
"Score":[85,92,78]}
df=pd.DataFrame(data)
df
# Out:
#    ID Students  Score
# 0   1    Rahul     85
# 1   2    Sneha     92
# 2   3    Arjun     78

# %% [markdown]
# Assign column names ["EmpID", "EmpName", "Salary"] to the employee DataFrame.

# %%
df.columns=[["Emp_Id","Name",
             "Salary"]]

# %%
df
# Out:
#   Emp_Id   Name Salary
# 0      1  Rahul     85
# 1      2  Sneha     92
# 2      3  Arjun     78

# %% [markdown]
# ## C.Observation & Generalization Questions

# %% [markdown]
# Given Data
#
# - marks = [1, 2, 43, 4]
# - expenses = [12000, 15000, 11000, 18000]

# %% [markdown]
#  Convert the Series created from marks into a DataFrame.
# - First, create a Series using marks.
# - Then convert that Series into a DataFrame

# %%
import pandas as pd
import numpy as np

# %%
marks = [1, 2, 43, 4]
df=pd.Series(marks)
df=pd.DataFrame(df)
df
# Out:
#     0
# 0   1
# 1   2
# 2  43
# 3   4

# %% [markdown]
# Convert the Series created from expenses into a DataFrame.
# - First, create a Series using expenses.
# - Then convert that Series into a DataFrame.

# %%
expenses = [12000, 15000, 11000, 18000]
df1=pd.Series(expenses)
result=pd.DataFrame(df1)
result
# Out:
#        0
# 0  12000
# 1  15000
# 2  11000
# 3  18000

# %% [markdown]
# Print the index and column names after converting the Series (from      marks) into a DataFrame.
# Use appropriate attributes to display:
# Index
#
#
# Column names

# %%
marks = [1, 2, 43, 4]
df=pd.Series(marks)
df=pd.DataFrame(df)
df
# Out:
#     0
# 0   1
# 1   2
# 2  43
# 3   4

# %%
df.columns=["Marks"]

# %%
df
# Out:
#    Marks
# 0      1
# 1      2
# 2     43
# 3      4

# %%
print("index of marks:",df.index)
print("Column names:",df.columns)
# Out:
# index of marks: RangeIndex(start=0, stop=4, step=1)
# Column names: Index(['Marks'], dtype='object')

# %% [markdown]
#  4. Identify the number of rows and columns in the DataFrame converted    from marks.
# Use the appropriate attribute to determine:
# Number of rows
#
#
# Number of columns

# %%
df.shape
# Out:
# (4, 1)

# %%
rows,cols=df.shape

# %%
print("Rows:",rows)
print("columns:",cols)
# Out:
# Rows: 4
# columns: 1

# %% [markdown]
#    5. Create any Series and check its type.
# Create a Series using any list and check the type of the object.

# %%
df=pd.Series([1,3,4,5,6,78])
df.dtype
# Out:
# dtype('int64')
